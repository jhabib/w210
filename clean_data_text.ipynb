# %%
import re
import pandas as pd
from pymongo import MongoClient


# Clean up categorical columns
def clean_list_columns(inpt, regex_pat=r'[a-zA-Z]'):
    if not inpt:
        return []
    
    if not isinstance(inpt, basestring):
        inpt = str(inpt)
    elif not isinstance(inpt, str):
        inpt = inpt.encode('utf-8')
    
    inpt = inpt.split(",")
    temp = []
    for item in inpt:
        temp.append(''.join(re.findall(regex_pat, item)).lower())
    
    inpt = temp

    inpt = ",".join(inpt)
    inpt = inpt.lower()

    return inpt


def clean_numeric_columns(inpt, rexp=re.compile(r'\d+\.\d+')):
    if not inpt:
        return None
    
    if not isinstance(inpt, basestring):
        inpt = str(inpt)
    elif not isinstance(inpt, str):
        inpt = inpt.encode('utf-8')
    
    inpt = rexp.findall(inpt)
    if not inpt:
        return None
    
    return float(inpt[0])

# %%
# We do not need these columns as features, at least initially
omit_original = ['Unnamed: 0', 'access', 'calendar_las_updated', \
            'calendar_last_scraped', 'calendar_updated', 'city', \
            'country', 'country_code', 'description', 'first_review', \
            'host_about', 'host_location', 'host_name', 'host_picture_url', \
            'host_thumbnail_url', 'host_url', 'host_verifications', \
            'house_rules', 'interaction', 'jurisdiction_names', \
            'last_review', 'latitude', 'license', \
            'listing_url', 'longitude', 'market', 'medium_url', \
            'neighborhood_overview', 'neighbourhood', \
            'neighbourhood_group_cleansed', 'notes', 'picture_url', \
            'review_scores_accuracy', 'review_scores_checkin', \
            'review_scores_cleanliness', 'review_scores_communication', \
            'review_scores_location', 'scrape_id', 'smart_location', \
            'space', 'state', 'street', 'summary', 'thumbnail_url', \
            'transit', 'xl_picture_url', 'zipcode']

text_columns = ['description', 'host_about', 'house_rules', 
               'neighborhood_overview', 'notes', 'summary', 
               'review_scores_rating']

omit = []
for o in omit_original:
    if o not in text_columns:
        omit.append(o)

# We need to one_hot encode categorical columns
# cat_columns = ['bed_type', 'room_type', \
#                'neighbourhood_cleansed', \
#                'property_type', 'cancellation_policy', \
#                'host_response_time']

# list_columns = ['amenities',]

# numeric_columns = ['bathrooms', 'bedrooms', 'beds', 'cleaning_fee', \
#                        'guests_included', \
#                        'host_listings_count', \
#                        'host_total_listings_count']

# percent_columns = ['host_acceptance_rate', 'host_response_rate']

# date_columns = ['host_since', 'last_scraped']

# bool_columns = ['host_has_profile_pic', 'host_identity_verified']

# %%
# Read all the data from MongoDB; 
# We should be batch processing this
client = MongoClient('localhost', 27017)
db = client['airbnb']
coll = db['listings']
cursor = coll.find({})
    
data = []
for sample in cursor:
    for o in omit:
        sample.pop(o, None)
    
    data.append(sample)

data = pd.DataFrame(data)

# %%
text_cols_df = pd.DataFrame()
for tc in text_columns:
    text_cols_df[tc] = data[tc]

text_cols_df
# Out:
#                                               description  \
# 0       Three-bedroom in exclusive Seacliff neighborho...
# 1       Charming, private, peaceful hideaway 2 blocks ...
# 2       My place is close to Golden Gate Bridge, Park ...
# 3       Cozy, sunny single occupancy bedroom in a spac...
# 4       My place is close to Golden Gate Bridge, Lands...
# 5       Welcome to our cozy apartment located in the h...
# 6                Quite house, clean room, nice roommates.
# 7       Newly built cottage that comfortably sleeps 2....
# 8       My two story house is located in the quite sid...
# 9       Welcome to one of the coziest and charming hom...
# 10      Amazing views from this immense 3 bedroom/ 2 b...
# 11      Minutes to GG Bridge, GG Park, Museums, The Pr...
# 12      Beautiful and spacious private room in 2BDR ap...
# 13      Private room on top level of house with city a...
# 14      Our charming single family home (approximately...
# 15      This is a classic 1969 building in front of se...
# 16      You'll love the prime location, near the Golde...
# 17      Spacious, quiet and beautifully decorated, thi...
# 18      Incredible panoramic views of the ocean abound...
# 19      Spacious and comfortable master bedroom availa...
# 20      I'm renting out a one bedroom with a queen siz...
# 21      Enjoy a true SF experience like a local in thi...
# 22      Elegant two bedroom, two bath apartment with g...
# 23      Are you in San Francisco for the 50th Super Bo...
# 24      Remodeled, inviting 2 bedroom flat centrally l...
# 25      A great full flat (lower unit of two) in the h...
# 26      Located a block away from the iconic Haight-As...
# 27      Spare private bedroom with king bed in our spa...
# 28      **Summer Special** SF vacation apartment. Shor...
# 29      1408 Hayes St. was the grandmother’s quarters ...
# ...                                                   ...
# 243691  Heart of Fillmore: Light-filled artful Victori...
# 243692  A spacious, quiet, light filled 3BR home in th...
# 243693  Hi, here I am sharing my not too big 1br apart...
# 243694  Beautifully restored top floor condo with love...
# 243695  My place is located at the intersection of the...
# 243696  Remodeled second floor Victorian flat in the h...
# 243697  My place is close to The Mill, Blue Bottle Cof...
# 243698  Fully remodeled ~1900 sq ft flat in the heart ...
# 243699  Newly renovated 2-bedroom, 2-bathroom apartmen...
# 243700  Prime real estate and one of the most sought a...
# 243701  Great location! My place is close to The Mill,...
# 243702  Private room in a beautiful home!  Comfortable...
# 243703  New listing!  Light filled two-bedroom, locate...
# 243704  This apartment is available for lodging. Sleep...
# 243705  1600' square top floor of classic SF Victorian...
# 243706  Charming and spacious fully furnished Studio l...
# 243707  Bedroom 2 is a semi-private room with a comfor...
# 243708  This is a private room with shared bathroom in...
# 243709  HUGE designer junior one bedroom central to ab...
# 243710  Beautiful sunny loft with original San Francis...
# 243711  This lovely studio is recently renovated with ...
# 243712  A Queen Anne cottage built in 1890, it looks s...
# 243713  Renovated 1930s light and airy residential  Fr...
# 243714  •Large 2 bedroom on golden gate park •Excellen...
# 243715  Cozy in-law unit that looks over private, prof...
# 243716  This is the best location in San Francisco for...
# 243717  Beautiful, spacious, light-filled Edwardian ho...
# 243718  Going back in France for the holidays, so I am...
# 243719  Clean well decorated and very functional flat....
# 243720  Fillmore Penthouse, natural lighting and breat...
#
#                                                host_about  \
# 0       We are a family of four, all avid travelers.  ...
# 1       I LOVE San Francisco!! I mean, I am IN LOVE wi...
# 2                                                    None
# 3                                                    None
# 4       Retired Accounting Professional. Down to earth...
# 5                                                    None
# 6       Hello!\r\n\r\nI am currently in grad school pu...
# 7       San Francisco natives who own this home. Alexi...
# 8       Retired Accounting Professional. Down to earth...
# 9       Teresa is passionate about leadership, kaizen ...
# 10      Property Manager for Watt Property Management,...
# 11      We're backpackers at heart.  We've bagged over...
# 12      I enjoy seeing live music, traveling, surfing,...
# 13      I'm a native San Franciscan construction profe...
# 14                                                   None
# 15      I moved to SF after living in the East Bay for...
# 16                                                   None
# 17      My on going love affair with San Francisco mad...
# 18      I manage 40-50  properties in SF and the Russi...
# 19                                                   None
# 20                                                   None
# 21                                                   None
# 22                                                  Julie
# 23                                                   None
# 24      Friends would describe Todd and I as friendly,...
# 25      Hi, I'm Donal, computer software professional ...
# 26                                                   None
# 27      I am a late 20s male and live with my girlfrie...
# 28       I'm a journalist who often travels with my wife.
# 29      I've lived in San Francisco for years and year...
# ...                                                   ...
# 243691  I'm a big fan of my hometown of San Francisco....
# 243692  My husband and I have both been in San Francis...
# 243693                                               None
# 243694                  Software Engineer from California
# 243695                                               None
# 243696                                               None
# 243697  Husband, Father & Tech Entrepreneur. Smiling 9...
# 243698  We are a couple in our mid-thirties. Pete work...
# 243699  I'm a working professional in SF–originally fr...
# 243700  Born and raised in southern California, lived ...
# 243701                                               None
# 243702  I have been a happy resident of San Francisco ...
# 243703                                               None
# 243704  Hi I'm Markus! A life long San Francisco resid...
# 243705                                               None
# 243706                                               None
# 243707                                               None
# 243708                                               None
# 243709                                               None
# 243710            French Canadian living in San Francisco
# 243711  I was born in New York and grew up in Houston,...
# 243712  Our home is occupied by Nico, a 50 yo environm...
# 243713  San Francisco Local. Avid Traveler when I can....
# 243714  We are a couple with a daughter and son. We li...
# 243715  I'm from San Francisco and enjoy a combination...
# 243716  Fabulous monthly and nighty rentals.  We have ...
# 243717  I was born and raised in a small farm in the s...
# 243718                                               None
# 243719  French young professional, sporty and dynamic....
# 243720  learner > laugher > lovely to meet you.\r\n\r\...
#
#                                               house_rules  \
# 0                                                    None
# 1       Absolutely NO SMOKING or drugs on property - p...
# 2                                                    None
# 3                                                    None
# 4       - 1, Front door of the house need to be lock a...
# 5       No shoes inside, no loud music after 10pm out ...
# 6                                                    None
# 7       Please treat house respectfully and keep in mi...
# 8       1.  No pets, no smoking inside the house. 2. F...
# 9                                                    None
# 10      1. Smoking is NOT allowed in the Property, Com...
# 11      We have neighbors (a family) and guests (also ...
# 12      There is a guide book full of information and ...
# 13      This is a shoeless house and slippers are prov...
# 14      Please be respectful of the property and leave...
# 15                                                   None
# 16                                                   None
# 17      Check in is anytime after 4:00, check out is 1...
# 18      No Smoking. No unauthorized guests. Pet consid...
# 19                                                   None
# 20                                                   None
# 21      We feel lucky to live here, so please treat ou...
# 22                                           No smoking.
# 23                                                   None
# 24      - Check-in time: 5 P.M. Check out time: 11 A.M...
# 25      $250 security deposit fully refundable will be...
# 26      Parties/Gatherings: This is a beautiful and co...
# 27                                                   None
# 28                                                   None
# 29      Please no smoking.  Unfortunately we cannot ac...
# ...                                                   ...
# 243691  As it's a duplex apartment, we request that yo...
# 243692  We do not allow pets, smoking or parties.  We ...
# 243693  There is not too many rules I can list of but ...
# 243694                  -Please remove shoes when inside.
# 243695                                               None
# 243696  We love our place and while we want you to mak...
# 243697                                               None
# 243698  • Check-in time is 3PM. * No smoking indoors a...
# 243699  - No shoes in the house please! Read on about ...
# 243700  This is a  5 unit building so out of respect f...
# 243701  - No parties or guests other than those on the...
# 243702  We share a neat and clean house which requires...
# 243703  No smoking No garage or driveway parking No pa...
# 243704  No outside guests or parties. Please be respec...
# 243705                                               None
# 243706                     - Quiet Hours between 10pm-8am
# 243707  •      Valid ID is required at check in (drive...
# 243708                            Quiet hours 10pm to 8am
# 243709                                               None
# 243710                                               None
# 243711  - No parties, no exceptions! - No smoking in t...
# 243712  Please be clean and decent and respectful of o...
# 243713  Thanks in advance for respecting house rules. ...
# 243714  No smoking in the flat No moving furniture No ...
# 243715  Please:  1. Lock all doors 2. Do not put anyth...
# 243716  no smoking , no pets please thank you for abid...
# 243717  Must be okay with sharing the bathroom with ro...
# 243718                                               None
# 243719                                               None
# 243720  no:  drugs guests stove usage ... *quiet hours...
#
#                                     neighborhood_overview  \
# 0                                                    None
# 1       I'm excited for you to discover why I love liv...
# 2                                                    None
# 3                                                    None
# 4       This is a Muti culture neighborhood that inclu...
# 5                                                    None
# 6                                                    None
# 7        Quiet neighborhood that is half a block from ...
# 8       It is in the city and close to everything. Par...
# 9       Three blocks away on Clement Street are plenty...
# 10      The neighborhood includes Legion of Honor, Sut...
# 11      For those who love the outdoors and good food,...
# 12      Surrounded by nature, with access to parks, hi...
# 13      The area around Lincoln Park is a residential ...
# 14      One of the most beautiful parts of San Francsi...
# 15                                                   None
# 16                                                   None
# 17      A favorite spot for both tourists and locals, ...
# 18                                                   None
# 19                                                   None
# 20      The neighborhood is quiet and just far enough ...
# 21      Close to iconic Haight Ashbury, borders Buena ...
# 22      Located on a quiet, quintessentially charming ...
# 23                                                   None
# 24      Central location in San Francisco one block of...
# 25      The North Panhandle is a hip, vibrant area in ...
# 26                                                   None
# 27                                                   None
# 28      We're in the NOPA district. Just a few short b...
# 29                                                   None
# ...                                                   ...
# 243691                                               None
# 243692  This home is really the best of all worlds in ...
# 243693  - This apartment is super centrally located. Y...
# 243694                                               None
# 243695                                               None
# 243696  Lower Haight is a historic and charming neighb...
# 243697                                               None
# 243698  We are in the Alamo Square/NOPA neighborhood--...
# 243699                                               None
# 243700  Considered lower Haight/Hayes Valley area. It ...
# 243701  I live in a great neighborhood with easy walki...
# 243702  I LOVE my neighborhood. First of all, Alamo Sq...
# 243703  The Lower Haight belongs to the highly desirab...
# 243704  Safe neighborhood, great nightlife, restaurant...
# 243705                                               None
# 243706  Hayes Valley is simply one of the city's most ...
# 243707  Centrally-located in Hayes Valley at the cente...
# 243708                                               None
# 243709                                               None
# 243710                                               None
# 243711  The location is the best feature of this studi...
# 243712                                               None
# 243713  Sleepy local safe seaside residential area whe...
# 243714  NEIGHBORHOOD The Sunset is a safe, family frie...
# 243715  Cole Valley is a very safe, charming and frien...
# 243716  Fabulous Oceanfront location next to Golden Ga...
# 243717  THE NEIGHBORHOOD The Inner Richmond is a charm...
# 243718  Named for the 1776-built Mission Dolores, the ...
# 243719                                               None
# 243720  The Fillmore District is a historical neighbor...
#
#                                                     notes  \
# 0                                                    None
# 1       The studio is not equipped for cooking, nor is...
# 2                                                    None
# 3                                                    None
# 4       1, Since your room is on the top floor of the ...
# 5                                                    None
# 6                                                    None
# 7       there is great surfing, hiking, and golf cours...
# 8       The summer in San Francisco is cooler than any...
# 9                                                    None
# 10      We require a separate rental agreement to be s...
# 11                                                   None
# 12      If ever you have a question about anything in ...
# 13      We encourage guests to make themselves at home...
# 14                 All linens and towels included in fee.
# 15                                                   None
# 16                                                   None
# 17      Street parking is easy if you have a car, you ...
# 18         This middle floor unit is a 2nd floor walk up
# 19                                                   None
# 20                                                   None
# 21                                                   None
# 22                                                   None
# 23                                                   None
# 24      This is our home and we love and know are neig...
# 25                                                   None
# 26      Please note that we do not have extra parking ...
# 27                                                   None
# 28                                                   None
# 29                                                   None
# ...                                                   ...
# 243691                                               None
# 243692  Please let us know if you have questions about...
# 243693                                               None
# 243694  We do have a cat but generally do not allow hi...
# 243695                                               None
# 243696                                               None
# 243697                                               None
# 243698  Security deposit may be required for longer st...
# 243699  This corner unit is on a main road, so opening...
# 243700                                               None
# 243701                                               None
# 243702  Beautiful Golden Gate Park with all of its man...
# 243703                                               None
# 243704                                               None
# 243705                                               None
# 243706                          STR-(PHONE NUMBER HIDDEN)
# 243707                                               None
# 243708                                               None
# 243709                                               None
# 243710                                               None
# 243711  This is a ground floor unit, however it does n...
# 243712                                               None
# 243713  Central heating and not working fireplace.  Ne...
# 243714  The flat is up one flight of stairs-about 15 s...
# 243715  STR-(PHONE NUMBER HIDDEN) There is a Nespresso...
# 243716  Please contact us for exact pricing and length...
# 243717  CALENDAR AND AVAILABILITY  My calendar is alwa...
# 243718                                               None
# 243719                                               None
# 243720                                               None
#
#                                                   summary  \
# 0       Three-bedroom in exclusive Seacliff neighborho...
# 1       Charming, private, peaceful hideaway 2 blocks ...
# 2       My place is close to Golden Gate Bridge, Park ...
# 3       Cozy, sunny single occupancy bedroom in a spac...
# 4       My place is close to Golden Gate Bridge, Lands...
# 5       Welcome to our cozy apartment located in the h...
# 6                Quite house, clean room, nice roommates.
# 7       Newly built cottage that comfortably sleeps 2....
# 8       My two story house is located in the quite sid...
# 9       Welcome to one of the coziest and charming hom...
# 10      Amazing views from this immense 3 bedroom/ 2 b...
# 11      Minutes to GG Bridge, GG Park, Museums, The Pr...
# 12      Beautiful and spacious private room in 2BDR ap...
# 13      Private room on top level of house with city a...
# 14      Our charming single family home (approximately...
# 15      This is a classic 1969 building in front of se...
# 16      You'll love the prime location, near the Golde...
# 17                                                   None
# 18      Incredible panoramic views of the ocean abound...
# 19      Spacious and comfortable master bedroom availa...
# 20      I'm renting out a one bedroom with a queen siz...
# 21      Enjoy a true SF experience like a local in thi...
# 22      Elegant two bedroom, two bath apartment with g...
# 23      Are you in San Francisco for the 50th Super Bo...
# 24      Remodeled, inviting 2 bedroom flat centrally l...
# 25      A great full flat (lower unit of two) in the h...
# 26      Located a block away from the iconic Haight-As...
# 27      Spare private bedroom with king bed in our spa...
# 28      **Summer Special** SF vacation apartment. Shor...
# 29                                                   None
# ...                                                   ...
# 243691  Heart of Fillmore: Light-filled artful Victori...
# 243692  A spacious, quiet, light filled 3BR home in th...
# 243693  Hi, here I am sharing my not too big 1br apart...
# 243694  Beautifully restored top floor condo with love...
# 243695  My place is located at the intersection of the...
# 243696  Remodeled second floor Victorian flat in the h...
# 243697  My place is close to The Mill, Blue Bottle Cof...
# 243698  Fully remodeled ~1900 sq ft flat in the heart ...
# 243699  Newly renovated 2-bedroom, 2-bathroom apartmen...
# 243700  Prime real estate and one of the most sought a...
# 243701  Great location! My place is close to The Mill,...
# 243702  Private room in a beautiful home!  Comfortable...
# 243703  New listing!  Light filled two-bedroom, locate...
# 243704  This apartment is available for lodging. Sleep...
# 243705                                               None
# 243706  Charming and spacious fully furnished Studio l...
# 243707  Bedroom 2 is a semi-private room with a comfor...
# 243708  This is a private room with shared bathroom in...
# 243709  HUGE designer junior one bedroom central to ab...
# 243710  Beautiful sunny loft with original San Francis...
# 243711  This lovely studio is recently renovated with ...
# 243712  A Queen Anne cottage built in 1890, it looks s...
# 243713  Renovated 1930s light and airy residential  Fr...
# 243714  •Large 2 bedroom on golden gate park •Excellen...
# 243715  Cozy in-law unit that looks over private, prof...
# 243716  This is the best location in San Francisco for...
# 243717  Beautiful, spacious, light-filled Edwardian ho...
# 243718  Going back in France for the holidays, so I am...
# 243719  Clean well decorated and very functional flat....
# 243720  Fillmore Penthouse, natural lighting and breat...
#
#         review_scores_rating
# 0                        NaN
# 1                       98.0
# 2                      100.0
# 3                       92.0
# 4                        NaN
# 5                      100.0
# 6                        NaN
# 7                       92.0
# 8                       90.0
# 9                        NaN
# 10                      80.0
# 11                      98.0
# 12                      96.0
# 13                      98.0
# 14                      95.0
# 15                       NaN
# 16                     100.0
# 17                      96.0
# 18                      90.0
# 19                       NaN
# 20                     100.0
# 21                     100.0
# 22                      97.0
# 23                       NaN
# 24                     100.0
# 25                       NaN
# 26                      96.0
# 27                     100.0
# 28                       NaN
# 29                      98.0
# ...                      ...
# 243691                  96.0
# 243692                 100.0
# 243693                  99.0
# 243694                  96.0
# 243695                 100.0
# 243696                  99.0
# 243697                  93.0
# 243698                  93.0
# 243699                 100.0
# 243700                  95.0
# 243701                  98.0
# 243702                 100.0
# 243703                  96.0
# 243704                  86.0
# 243705                  98.0
# 243706                  95.0
# 243707                 100.0
# 243708                  78.0
# 243709                 100.0
# 243710                  96.0
# 243711                  96.0
# 243712                 100.0
# 243713                  98.0
# 243714                  92.0
# 243715                  96.0
# 243716                  80.0
# 243717                  96.0
# 243718                   NaN
# 243719                   NaN
# 243720                   NaN
#
# [243721 rows x 7 columns]

# %%
dependent_variable='review_scores_rating'
text_cols_df = text_cols_df.dropna(subset=[dependent_variable])

# %%
print text_cols_df.shape
# Out:
# (190004, 7)

# %%
from sklearn.model_selection import train_test_split

Train, Test = train_test_split(text_cols_df, 
                               test_size=0.33, 
                               random_state=1234)
train_colnames = [c for c in Train.columns if c != dependent_variable]
test_colnames = [c for c in Test.columns if c!= dependent_variable]

print Train.shape
print Test.shape
# Out:
# (127302, 7)
# (62702, 7)

# %%
y_train = Train[dependent_variable].values
y_train = pd.DataFrame(y_train, columns = [dependent_variable])
X_train = Train.drop([dependent_variable], axis=1)
X_train = pd.DataFrame(X_train.values, columns=train_colnames)


y_test = Test[dependent_variable].values
y_test = pd.DataFrame(y_test, columns=[dependent_variable])
X_test = Test.drop([dependent_variable], axis=1)
X_test = pd.DataFrame(X_test.values, columns=test_colnames)

# %%
# Write processed train data to csv
X_train.to_csv('./data/categorical_train_deps.csv', encoding='utf8')
y_train.to_csv('./data/categorical_train_indeps.csv', encoding='utf8')

# Write processed test data to csv
X_test.to_csv('./data/categorical_test_deps.csv', encoding='utf8')
y_test.to_csv('./data/categorical_test_indeps.csv', encoding='utf8')
