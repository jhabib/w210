# %% [markdown]
# # Process text data

# %% [markdown]
# # Files that we need to load
#
# - amenities_test_deps.csv
# - amenities_test_indeps.csv
# - amenities_train_deps.csv
# - amenities_train_indeps.csv
#
# - categorical_test_deps.csv
# - categorical_test_indeps.csv
# - categorical_train_deps.csv
# - categorical_train_indeps.csv
#
# - numeric_test_deps.csv
# - numeric_test_indeps.csv
# - numeric_train_deps.csv
# - numeric_train_indeps.csv

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
def read_df(filename, valtype):
    df = pd.read_csv(filename, low_memory=False, dtype=valtype)
    return df

# %%
from collections import OrderedDict, defaultdict

def create_combined_df(input_dict):
    fdf = pd.DataFrame()
    cols = OrderedDict()
    for k, v in input_dict.items():
        df = read_df('./data/'+k, v)
        colnames = [c for c in df.columns if c not in ['Unnamed: 0']]
        cols[k] = colnames
        fdf = pd.concat([fdf, df], axis=1)
    
    # fdf = fdf.DataFrame(fdf, columns=cols)
    fdf = fdf.drop(['Unnamed: 0'], axis=1)
    return fdf, cols

# %% [markdown]
# # Load Training Data

# %%
train_inpd = {
    'numeric_train_deps.csv': float, 
    'text_train_deps.csv': str,
}

X_train, cols = create_combined_df(train_inpd)
y_train = pd.read_csv('./data/numeric_train_indeps.csv', low_memory=False)
y_train = y_train.drop(['Unnamed: 0'], axis=1).astype(float)
y_train.sample()

print X_train.shape
print y_train.shape
X_train.sample()
y_train.sample()
# Out:
# (127302, 18)
# (127302, 1)
#        review_scores_rating
# 88033                  87.0

# %%
numeric_cols = cols['numeric_train_deps.csv']
text_cols = cols['text_train_deps.csv']

# %%
train_colnames = X_train.columns
dependent_variable = y_train.columns[0]

# %% [markdown]
# # Load Test Data

# %%
test_inpd = {
    'numeric_test_deps.csv': float, 
    'text_train_deps.csv': str,
}

X_test, cols = create_combined_df(test_inpd)
y_test = pd.read_csv('./data/numeric_test_indeps.csv', low_memory=False)
y_test = y_test.drop(['Unnamed: 0'], axis=1).astype(float)
y_test.sample()

print X_test.shape
print y_test.shape
X_test.sample()
y_test.sample()
# Out:
# (127302, 18)
# (62702, 1)
#        review_scores_rating
# 16536                  97.0

# %%
import numpy as np

def get_rand_idxs(start, end, size, seed=1234):
    np.random.seed(seed)
    return np.random.randint(start, end, size)

# %%
def run_prediction(X, y, Xt, yt, model):
    if len(y.shape) == 1:
        y = y.reshape(-1, 1)
    if len(yt.shape) == 1:
        yt = yt.reshape(-1, 1)
    
    res = {'train': {}, 'test': {}}
    
    model.fit(X, y)
    
    train_pred = model.predict(X)
    res['train']['pred'] = train_pred
    
    test_pred = model.predict(Xt)
    res['test']['pred'] = test_pred
    
    
    for name, tup in zip(['train', 'test'], [(y, train_pred), (yt, test_pred)]):
        act, prd = tup[0].ravel(), tup[1].ravel()
        print 'Results for %s' % name
        
        mserr = mean_squared_error(act, prd)
        res[name]['mse'] = mserr
        print '%s Mean Squared Error: %.4f' % (name, mserr)
        
        rsq_score = r2_score(act, prd)
        res[name]['r2'] = rsq_score
        print '%s R-Squared: %.4f' % (name, rsq_score)
        
        plt.scatter(act, prd, alpha=0.5)
        plt.title(name+': predictions vs. actual')
        plt.show()
        plt.scatter(act, act-prd, alpha=0.5)
        plt.title(name+': residuals vs. actual')
        plt.show()
        plt.hist(act-prd, alpha=0.5)
        plt.title(name+': residuals histogram')
        plt.show()
    
    return res

# %% [markdown]
# # Impute missing values for Train and Test sets
# We will use Median for imputing missing values because it is not as affected by outliers as the Mean.
# We will train the Imputer on the training data, and use this to fill the values for both Train and Test sets.
# We will not train a new Imputer on test data. This is important because we do not want to look at the test data when imputing the values.

# %%
X_num_train = X_train[numeric_cols]
X_num_test = X_test[numeric_cols]

# %%
print X_num_train.shape
print X_num_test.shape
# Out:
# (127302, 12)
# (127302, 12)

# %%
# Impute missing values using median for both independent and dependent variables
# We don't care for host_has_profile_pic, and host_identity_verified.
# We dropped missing values from our dependent variable earlier, 
# so it won't be affected by imputation here.

import numpy as np
from sklearn.preprocessing import Imputer

# We need the 
num_train_colnames = X_num_train.columns

# Train data first
# axis 0 means impute along columns
train_imp = Imputer(missing_values=np.nan, strategy='median', axis=0, copy=True)
train_imp.fit(X_num_train)
X_train_imp = train_imp.transform(X_num_train)


# Then Test data
num_test_colnames = X_num_test.columns
X_test_imp = train_imp.transform(X_num_test)

print X_train_imp.shape
print X_test_imp.shape
# Out:
# (127302, 12)
# (127302, 12)

# %%
print len(num_train_colnames)
# Out:
# 12

# %% [markdown]
# # Handle Outliers
# Drop them from Training data, as discussed in the Takeaways section.

# %%
# all_columns = list(train_colnames.values) + [dependent_variable]

# %%
Train = pd.DataFrame(X_train_imp, columns=num_train_colnames)
Train = pd.concat([Train, X_train[text_cols]], axis=1)
Train = pd.concat([Train, y_train], axis=1)
print Train.shape
# Out:
# (127302, 19)

# %%
Test = pd.DataFrame(X_test_imp, columns=num_test_colnames)
Test = pd.concat([Test, X_test[text_cols]], axis=1)
Test = pd.concat([Test, y_test], axis=1)

# %%
print Test.shape
# Out:
# (127302, 19)

# %%
Test.loc[Test.reviews_per_month > 0]
# Out:
#         bathrooms  bedrooms  beds  cleaning_fee  guests_included  \
# 0             1.0       1.0   1.0          25.0              1.0
# 1             1.0       1.0   1.0          20.0              1.0
# 2             1.0       1.0   1.0          70.0              1.0
# 3             1.0       1.0   1.0          70.0              1.0
# 4             2.0       1.0   1.0          70.0              1.0
# 5             1.0       1.0   1.0          25.0              1.0
# 6             1.0       1.0   1.0          50.0              1.0
# 7             1.5       3.0   5.0         150.0              6.0
# 8             1.0       1.0   1.0          70.0              2.0
# 9             1.0       1.0   2.0          75.0              2.0
# 10            1.0       1.0   2.0          50.0              1.0
# 11            1.0       1.0   1.0          25.0              1.0
# 12            2.0       2.0   2.0         150.0              1.0
# 13            1.0       2.0   2.0         100.0              4.0
# 14            1.5       2.0   2.0         100.0              1.0
# 15            1.0       1.0   1.0          40.0              1.0
# 16            1.5       1.0   1.0         170.0              1.0
# 17            1.5       1.0   1.0          20.0              2.0
# 18            1.0       2.0   2.0          80.0              4.0
# 19            1.0       1.0   2.0          75.0              2.0
# 20            1.0       1.0   3.0          50.0              1.0
# 21            1.0       1.0   1.0         150.0              1.0
# 22            1.0       1.0   1.0          30.0              1.0
# 23            1.5       2.0   3.0         175.0              4.0
# 24            1.0       1.0   1.0          70.0              1.0
# 25            1.0       2.0   2.0         104.0              1.0
# 127287  The apartment is located in the heart of SF No...
# 127288                                               None
# 127289  The Valencia corridor is home to many restaura...
# 127290  Pacific Height is my favorite neighborhood The...
# 127291  Our neighborhood is one of the trendiest up an...
# 127292  The neighborhood puts you at the center of wha...
# 127293                                               None
# 127294  Please note that the house is NOT in downtown ...
# 127295  mile to Glen Park Canyon a 70 acre city park w...
# 127296  This is a beautiful sunny and central neighbor...
# 127297                                               None
# 127298  Walking distance to Golden Gate Parks the De Y...
# 127299  We have lived here for 17 years we love everyt...
# 127300  The neighborhood NOPA stands for North Of the ...
# 127301                                               None
#
#                                                     notes  \
# 0                                                    None
# 1       You will be hard pressed to find a better loca...
# 2       Parking is available with advance notice This ...
# 3                                                    None
# 4       This bedroom has twin beds flat screen TV with...
# 5       We are 1 mile from the beach The beach is seve...
# 6       Please note for groups of more than two I requ...
# 7       San Francisco Short Term Residential Rental Ce...
# 8       COMMUNITY A portion of the income from the Mis...
# 9       I really do love to make everyone s stay in Sa...
# 10                                                   None
# 11                                                   None
# 12      Guests should be able to walk up 2 flights of ...
# 13      Car park circa 10 per day compare financial di...
# 14                                                   None
# 15      Permit Number STR PHONE NUMBER HIDDEN Mission ...
# 16                                                   None
# 17      There are 8 very large drawers in the master b...
# 18      We would love to accommodate you and take spec...
# 19      There is an apartment above the Love Nest wher...
# 20      Our resident cat Nikita will gladly stay with ...
# 21      We are family friendly and Bernal Heights is t...
# 22      Ours is a kid friendly home we have two Howeve...
# 23                                                   None
# 24                                                   None
# 25      If you re driving into San Francisco please no...
# 26                                                    NaN
# 27                                                   None
# 28                                                    NaN
# 29                                                   None
# ...                                                   ...
# 127272  The house is not handicap accessible as there ...
# 127273  1 No in house laundry available but there are ...
# 127274                                               None
# 127275  I have a friendly small dog named Mojito My si...
# 127276  Quiet Hours are 10 00 PM to 8 00 AM on weeknig...
# 127277  Three other units in the building these lovely...
# 127278  Free Parking for our Airbnb guests versus 80 n...
# 127279  You may choose to prepare your own meals in yo...
# 127280                                               None
# 127281  Just call me when you re nearby and I ll give ...
# 127282                                               None
# 127283                                               None
# 127284                                               None
# 127285  We welcome all guests regardless of national o...
# 127286                                               None
# 127287  This is our home please treat it as you would ...
# 127288                                               None
# 127289  A short haired dog lives here While the flat i...
# 127290                                               None
# 127291                                               None
# 127292  Though the unit will usually not be available ...
# 127293                                               None
# 127294                                               None
# 127295  Considered to be one of the hottest neighborho...
# 127296                                               None
# 127297                                               None
# 127298  Outdoor cats live at the property They may run...
# 127299  Our garden is having a facelift hammock tikki ...
# 127300                                               None
# 127301                                               None
#
#                                                   summary  \
# 0                 San Francisco Station AT T Park Safeway
# 1       a Private Bedroom in a classic Victorian one b...
# 2       STR phone number hidden Private entrance bathr...
# 3       Great place to call a home in SF newly remodel...
# 4       Enjoy the lovely South Hill neighborhood of Sa...
# 5       Built 1931 the 3BR 2 5BA is elegant but family...
# 6       Hi Welcome Gorgeous unobstructed views of the ...
# 7       Legal SF City approved one bedroom one bathroo...
# 8       A modern studio off a secluded garden court wi...
# 9       Enjoy 2 private bedrooms in a beautiful home l...
# 10      Trendy condo with sexy cool lines and applianc...
# 11      This apartment is perfectly configured for an ...
# 12      My place is good for couples solo adventurers ...
# 13      Entire condo for minimum 30 days Alcatraz and ...
# 14                                                   None
# 15      Bright natural light new NEST high end plush b...
# 16      My place is two blocks from Haight Ashbury Hai...
# 17      This beautiful Edwardian is close to restauran...
# 18      My place is close to Golden Gate Park Ocean Be...
# 19      Greetings Masters of the Universe Thank you fo...
# 20      This beautiful large well appointed 2BR flat h...
# 21      Our garden studio is clean and Modern Designer...
# 22      Huge bright top floor flat in a prominent Vict...
# 23      The Beach Hideaway is a charming single family...
# 24      This gorgeous 3 bedroom home is ready for a pe...
# 25      Centrally located in the heart of SF this is t...
# 26      This large one bedroom apartment is on the ver...
# 27      This apartment was just painted and furnished ...
# 28      Hi we just launched our new startup Yogaliciou...
# 29      Our spacious home is located in the heart of S...
# ...                                                   ...
# 127272  We have a guest bedroom in our 4 bedroom apart...
# 127273  1 15 mins from to SFO airport by Subway or Car...
# 127274  Amazing Edwardian Building with true San Franc...
# 127275  Private room with queen bed in a 2 bedroom fla...
# 127276  Our home is located in a quiet neighborhood at...
# 127277  Our darling condo in NoeValley has all you cou...
# 127278  Spacious 2 bedrooms with living room dinning r...
# 127279  MODERN SPACIOUS CHIC SWANK AND STYLISH NEW YOR...
# 127280  Located in a 1906 row house this spacious room...
# 127281  You ll get your own private space BR bathroom ...
# 127282  Charming 1 bedroom apartment in the heart of t...
# 127283  My nice one bedroom apartment in Sunset distri...
# 127284  This is one of the most happening neighborhood...
# 127285  Great for business travelers couples weekender...
# 127286  Charming 3 bedroom with lovely garden in a saf...
# 127287  3BR 2BA modern apartment with some of the best...
# 127288                                               None
# 127289  This stylish and comfortable flat is in the he...
# 127290  Walk Score 97 Transit Score 89 0 5 blocks to F...
# 127291  Located in the Alamo Square neighborhood w 95 ...
# 127292  Gorgeous modern sunlight soaked luxury apartme...
# 127293  A large pleasant private bedroom in the carria...
# 127294  I have a sunny room available on the 2nd floor...
# 127295  Small village feel in the big city Beautifully...
# 127296  A chic and comfortable room in a designer s ow...
# 127297  This room is an art filed private room off of ...
# 127298  This house has a great location on a quiet str...
# 127299  Our sunny ground floor two bedroom apartment h...
# 127300  Just three blocks from the city epicenter and ...
# 127301  Our spacious home is located in the heart of S...
#
#         review_scores_rating
# 0                      100.0
# 1                      100.0
# 2                       89.0
# 3                       73.0
# 4                       69.0
# 5                      100.0
# 6                      100.0
# 7                       96.0
# 8                      100.0
# 9                      100.0
# 10                      95.0
# 11                      98.0
# 12                     100.0
# 13                      93.0
# 14                     100.0
# 15                      93.0
# 16                     100.0
# 17                     100.0
# 18                      98.0
# 19                      94.0
# 20                     100.0
# 21                      93.0
# 22                     100.0
# 23                      97.0
# 24                      91.0
# 25                      93.0
# 26                      85.0
# 27                     100.0
# 28                      98.0
# 29                      98.0
# ...                      ...
# 127272                   NaN
# 127273                   NaN
# 127274                   NaN
# 127275                   NaN
# 127276                   NaN
# 127277                   NaN
# 127278                   NaN
# 127279                   NaN
# 127280                   NaN
# 127281                   NaN
# 127282                   NaN
# 127283                   NaN
# 127284                   NaN
# 127285                   NaN
# 127286                   NaN
# 127287                   NaN
# 127288                   NaN
# 127289                   NaN
# 127290                   NaN
# 127291                   NaN
# 127292                   NaN
# 127293                   NaN
# 127294                   NaN
# 127295                   NaN
# 127296                   NaN
# 127297                   NaN
# 127298                   NaN
# 127299                   NaN
# 127300                   NaN
# 127301                   NaN
#
# [127294 rows x 19 columns]

# %%
def drop_outliers(t):
    # Drop outliers from dependent variable
    h = 0
    if 'review_scores_value' == dependent_variable:
        h = 3
    elif 'review_scores_rating' == dependent_variable:
        h = 80
    t = t.loc[t[dependent_variable] >= h]
    
    # Remove reviews_per_month == 0
    t = t.loc[t.reviews_per_month > 0]

    # 1. Remove 'bathrooms' >= 5, convert to int
    t = t.loc[t.bathrooms < 5]
    t.bathrooms = t.bathrooms.astype(int)

    # 2. Remove 'bedrooms' > 5, convert to int
    t = t.loc[t.bedrooms <= 5]
    t.bedrooms = t.bedrooms.astype(int)

    # 3. Remove 'beds' >= 8, convert to int
    t = t.loc[t.beds < 8]
    t.beds = t.beds.astype(int)

    # 4. Remove 'cleaning_fee' > 400
    t = t.loc[t.cleaning_fee <= 400]

    # 5. Remove 'guests_included' > 8
    t = t.loc[t.guests_included <= 8]
    t = t.loc[t.guests_included > 0]
    t.guests_included = t.guests_included.astype(int)

    # 6. Remove 'host_listings_count' > 100
    t = t.loc[t.host_listings_count <= 100]
    # Remove'host_listings_count' <= 0
    t = t.loc[t.host_listings_count > 0]
    t.host_listings_count = t.host_listings_count.astype(int)
    
    

    # 7. Remove 'host_acceptance_rate' == 0.
    t = t.loc[t.host_acceptance_rate > 0.]

    # 8. Remove 'host_response_rate' == 0.
    t = t.loc[t.host_acceptance_rate > 0.]

    # 9. Remove 'reviews_per_month' > 12.
    t = t.loc[t.reviews_per_month <= 12]
    
    return t

# %%
Train = drop_outliers(Train)
Test = drop_outliers(Test)

# %%
np.unique(Train.review_scores_rating)
# Out:
# array([ 80.,  81.,  82.,  83.,  84.,  85.,  86.,  87.,  88.,  89.,  90.,
#         91.,  92.,  93.,  94.,  95.,  96.,  97.,  98.,  99., 100.])

# %%
np.unique(Test.review_scores_rating)
# Out:
# array([ 80.,  81.,  82.,  83.,  84.,  85.,  86.,  87.,  88.,  89.,  90.,
#         91.,  92.,  93.,  94.,  95.,  96.,  97.,  98.,  99., 100.])

# %% [markdown]
# # Separate the Dependent and Independet Variables

# %%
# Train data
y_train = Train[dependent_variable]
print y_train.shape

X_train = Train.drop([dependent_variable], axis=1)
print X_train.shape

# Test data
y_test = Test[dependent_variable]
print y_test.shape

X_test = Test.drop([dependent_variable], axis=1)
print X_test.shape
# Out:
# (119615,)
# (119615, 18)
# (58911,)
# (58911, 18)

# %% [markdown]
# # Write back all data to csv

# %%
# Write numeric data

# %%
y_train = pd.DataFrame(y_train, columns=[dependent_variable])
y_test = pd.DataFrame(y_test, columns=[dependent_variable])

# %% [raw]
# X_train_num.to_csv('./data/fin_num_train_deps.csv', encoding='utf8')
# y_train.to_csv('./data/fin_train_indeps.csv', encoding='utf8')
# X_test_num.to_csv('./data/fin_num_test_deps.csv', encoding='utf8')
# y_test.to_csv('./data/fin_test_indeps.csv', encoding='utf8')

# %%
# Write text data

# %%
X_train_text = X_train[text_cols]
X_test_text = X_test[text_cols]

# %%
X_train_text.to_csv('./data/fin_text_train_deps.csv', encoding='utf8')
X_test_text.to_csv('./data/fin_text_test_deps.csv', encoding='utf8')

# %%
# Write amenities columns

# %%
print (X_train_text.shape)
print (X_test_text.shape)
# Out:
# (119615, 6)
# (58911, 6)
