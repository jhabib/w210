# %% [markdown]
# # Regression using Numeric, Bool and Date features
# We saw that regression on numeric features produced an r-squared value of 0.06 which is awful. Let's add the bool features and date features, and see if that does better.

# %%
# %matplotlib inline

# %%
import pandas as pd

# %% [markdown]
# # Load Numeric Data

# %%
num_data = pd.read_csv('./data/numeric_features.csv', low_memory=False, dtype=float)
print num_data.columns
num_data = num_data.drop('Unnamed: 0', axis=1)
num_data['id'] = num_data['id'].astype(int).astype("category")
num_data.shape
# Out:
# Index([u'Unnamed: 0', u'id', u'bathrooms', u'bedrooms', u'beds',
#        u'cleaning_fee', u'guests_included', u'host_listings_count',
#        u'host_total_listings_count', u'host_acceptance_rate',
#        u'host_response_rate'],
#       dtype='object')
# (243721, 10)

# %% [markdown]
# # Load Bool Data

# %%
bool_data = pd.read_csv('./data/bool_features.csv', low_memory=False, dtype=int)
print bool_data.columns

bool_data = bool_data.drop('Unnamed: 0', axis=1)
bool_data['id'] = bool_data['id'].astype(int).astype("category")

bool_data.host_has_profile_pic = bool_data.host_has_profile_pic.astype(bool)
bool_data.host_identity_verified = bool_data.host_identity_verified.astype(bool)

print bool_data.shape
# Out:
# Index([u'Unnamed: 0', u'id', u'host_has_profile_pic',
#        u'host_identity_verified'],
#       dtype='object')
# (243721, 3)

# %%
# Load Date Data
parse_dates = ['host_since', 'last_scraped', 'days_delta']
date_data = pd.read_csv('./data/date_features.csv', low_memory=False, parse_dates=parse_dates)
print date_data.columns


date_data = date_data.drop('Unnamed: 0', axis=1)
date_data['id'] = date_data['id'].astype(int).astype("category")
date_data.days_delta = date_data.days_delta.apply(lambda x: x.split(' ')[0]).astype(float)

print date_data.shape
date_data.sample()
# Out:
# Index([u'Unnamed: 0', u'id', u'host_since', u'last_scraped', u'days_delta'], dtype='object')
# (243721, 4)
#            id host_since last_scraped  days_delta
# 44941  213532 2011-08-29   2018-03-04      2379.0

# %% [markdown]
# # Load Reviews Data (Dependent variable)

# %%
reviews_data = pd.read_csv('./data/reviews_features.csv', low_memory=False, dtype=float)
print reviews_data.columns

reviews_data = reviews_data.drop('Unnamed: 0', axis=1)
reviews_data['id'] = reviews_data['id'].astype(int).astype("category")
print reviews_data.shape
reviews_data.sample()
# Out:
# Index([u'Unnamed: 0', u'id', u'number_of_reviews', u'review_scores_rating',
#        u'review_scores_value', u'reviews_per_month'],
#       dtype='object')
# (243721, 5)
#              id  number_of_reviews  review_scores_rating  review_scores_value  \
# 135642  8053481               17.0                  98.0                  9.0
#
#         reviews_per_month
# 135642               0.75

# %% [markdown]
# ## We can use reviews_per_month as an independent variable

# %%
# Generate random indexes for our sample
import numpy as np

np.random.seed(1234)
sample_size=10000
idxs = np.random.randint(0, num_data.shape[0], 10000)
idxs
# Out:
# array([224047, 189139, 165158, ..., 149821, 130353, 163357])

# %%
# Set the dependent variable 
dependent_variable = 'review_scores_rating'

# Select the independent variables and get a combined dataset
data = pd.concat([num_data.loc[idxs], 
                  bool_data.loc[idxs][['host_has_profile_pic', 'host_identity_verified']], 
                  date_data.loc[idxs][['days_delta']], 
                  reviews_data.loc[idxs][['reviews_per_month', dependent_variable]]], axis=1)
data.sample(10)
# Drop missing values from depedent variable
data = data.dropna(subset=[dependent_variable])

# %%
print data.shape
print data.columns
# Out:
# (7793, 15)
# Index([u'id', u'bathrooms', u'bedrooms', u'beds', u'cleaning_fee',
#        u'guests_included', u'host_listings_count',
#        u'host_total_listings_count', u'host_acceptance_rate',
#        u'host_response_rate', u'host_has_profile_pic',
#        u'host_identity_verified', u'days_delta', u'reviews_per_month',
#        u'review_scores_rating'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
for c in data.columns:
    if 'id' != c:
        print c
        lst = list(data[c].fillna(data[c].median()))
        plt.hist(lst, bins=10, alpha=0.5)
        plt.show()
# Out:
# bathrooms
# bedrooms
# beds
# cleaning_fee
# guests_included
# host_listings_count
# host_total_listings_count
# host_acceptance_rate
# host_response_rate
# review_scores_rating

# %%
y_vals = data[dependent_variable].fillna(data[dependent_variable].mean())
for c in data.columns:
    if c not in ['id', dependent_variable]:
        print c
        lst = list(data[c].fillna(np.nanmedian(data[c])))
        # lst = np.sqrt(lst) / np.var(lst)
        plt.scatter(lst, y_vals, alpha=0.25)
        plt.show()
# Out:
# bathrooms
# bedrooms
# beds
# cleaning_fee
# guests_included
# host_listings_count
# host_total_listings_count
# host_acceptance_rate
# host_response_rate

# %% [markdown]
# # Takeaways
# 1. Remove 'bathrooms' >= 5
# 2. Remove 'bedrooms' > 5
# 3. Remove 'beds' >= 8
# 4. Remove 'cleaning_fee' >= 400
# 5. Remove 'guests_included' > 8
# 6. Remove 'host_listings_count' > 100
# 7. Drop 'host_total_listings_count'
# 8. Remove 'host_acceptance_rate' == 0.
# 9. Remove 'host_response_rate' == 0.

# %%
# Drop outliers from dependent variable
data = data.loc[data[dependent_variable] >= 80]

# 1. Remove 'bathrooms' >= 5, convert to int
data = data.loc[data.bathrooms < 5]
data.bathrooms = data.bathrooms.astype(int)

# 2. Remove 'bedrooms' > 5, convert to int
data = data.loc[data.bedrooms <= 5]
data.bedrooms = data.bedrooms.astype(int)

# 3. Remove 'beds' >= 8, convert to int
data = data.loc[data.beds < 8]
data.beds = data.beds.astype(int)

# 4. Remove 'cleaning_fee' > 400
data = data.loc[data.cleaning_fee <= 400]

# 5. Remove 'guests_included' > 8
data = data.loc[data.guests_included <= 8]
data.guests_included = data.guests_included.astype(int)

# 6. Remove 'host_listings_count' > 100
data = data.loc[data.host_listings_count <= 100]
data.host_listings_count = data.host_listings_count.astype(int)

# 7. Drop 'host_total_listings_count'
data = data.drop('host_total_listings_count', axis=1)

# 8. Remove 'host_acceptance_rate' == 0.
data = data.loc[data.host_acceptance_rate > 0.]

# 9. Remove 'host_response_rate' == 0.
data = data.loc[data.host_acceptance_rate > 0.]

# %%
data.shape
data.sample(10)
# Out:
#               id  bathrooms  bedrooms  beds  cleaning_fee  guests_included  \
# 130353  13469139          1         1     1          40.0                1
# 220252   7967149          1         3     3         100.0                1
# 187690   1300810          1         2     3          70.0                1
# 58600    5033949          1         2     3         100.0                3
# 69534    4661955          1         1     1          75.0                2
# 20613    8408710          1         1     1          20.0                2
# 19676    8474452          1         1     1          35.0                1
# 68349    6833179          1         2     3          50.0                5
# 183776   2802418          2         1     1          10.0                1
# 62008    1892250          1         1     1          60.0                2
#
#         host_listings_count  host_acceptance_rate  host_response_rate  \
# 130353                    2                  1.00                0.82
# 220252                    1                  1.00                0.83
# 187690                    1                  0.50                1.00
# 58600                     2                  1.00                0.88
# 69534                     1                  0.88                1.00
# 20613                     2                  1.00                1.00
# 19676                     1                  0.89                1.00
# 68349                     2                  0.89                1.00
# 183776                    1                  1.00                1.00
# 62008                     2                  0.94                1.00
#
#         review_scores_rating
# 130353                  87.0
# 220252                  94.0
# 187690                  95.0
# 58600                   89.0
# 69534                   96.0
# 20613                   98.0
# 19676                  100.0
# 68349                   85.0
# 183776                  94.0
# 62008                   97.0

# %%
# Create the X and y
# Drop the columns that we do not need
y = data[dependent_variable]
X = data.drop(['id', dependent_variable], axis=1)

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.33, 
                                                    random_state=1234)

# %%
# Impute missing values using median for both independent and dependent variables

import numpy as np
from sklearn.preprocessing import Imputer

imp = Imputer(missing_values=np.nan, strategy='median', axis=0)
imp.fit(X_train)
X_train = imp.transform(X_train)
X_test = imp.transform(X_test)

imp = Imputer(missing_values=np.nan, strategy='median', axis=1)
imp.fit(y_train)
y_train = imp.transform(y_train.values.reshape(-1,1))
y_train = y_train.ravel()
y_test= imp.transform(y_test.values.reshape(-1,1))
y_test = y_test.ravel()

print X_train.shape
print y_train.shape
print X_test.shape
print y_test.shape
# Out:
# (1078, 8)
# (1078,)
# (531, 8)
# (531,)

# %% [raw]
# # Scale the independent and dependent variables
# # Center the data around zero by subtracting the mean
# # Scale it to unit variance
# # This is helpful in PCA, if we choose to use it
#
# from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler(copy=True, with_mean=True, with_std=True)
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)
#
# scaler = StandardScaler(copy=True, with_mean=True, with_std=True)
# scaler.fit(y_train.reshape(-1,1))
# y_train = scaler.transform(y_train.reshape(-1,1))
# y_train = y_train.ravel()
# y_test = scaler.transform(y_test.reshape(-1,1))
# y_test = y_test.ravel()

# %%
plt.hist(y_train)
plt.show()

# %% [raw]
# # Divide each column by its variance
# # y_train = np.log(y_train + 1)
# # y_test = np.log(y_test + 1)
# x_train_var = X_train.var(axis=0)
# X_train = X_train / np.sqrt(x_train_var)
# X_test = X_test / np.sqrt(x_train_var)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, make_scorer, roc_auc_score

# Create linear regression object
regr = linear_model.Ridge(alpha=0.5, fit_intercept=True, max_iter=10000)

# Train the model using the training sets
regr.fit(X_train, y_train)

y_train_pred = regr.predict(X_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test.tolist(), y_pred.tolist()))

# Plot the residuals
plt.scatter(y_train, y_train-y_train_pred, c='b', marker='o', alpha=0.5)
plt.scatter(y_test, y_test-y_pred, c='g', marker='s', alpha=0.5)
plt.hlines(y=0, xmin=np.min(y_test), xmax=np.max(y_test), color='r')
plt.show()
# Out:
# Mean squared error: 22.95
# Variance score: 0.04

# %% [markdown]
# # Check for endogeneity

# %%
y_train_error = regr.predict(X_train) - y_train
for cname, c in zip(X.columns, X_train.T):
    print '%s: correlation coef: %s' % (cname, np.corrcoef(c.ravel(), y_train_error.ravel())[1, 0])
    plt.scatter(c.ravel(), y_train_error.ravel(), alpha=0.25)
    plt.show()
# Out:
# bathrooms: correlation coef: 4.13885440646927e-05
# bedrooms: correlation coef: -8.90812937352749e-06
# beds: correlation coef: 2.555623108533868e-05
# cleaning_fee: correlation coef: -3.3761893862359384e-08
# guests_included: correlation coef: 2.0463612866953005e-05
# host_listings_count: correlation coef: 9.179586293357662e-07
# host_acceptance_rate: correlation coef: 0.00025831112677072434
# host_response_rate: correlation coef: -0.001418422297017045

# %%
from sklearn import model_selection

from sklearn.linear_model import LinearRegression, Ridge, ElasticNet
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR


kfold = model_selection.KFold(n_splits=20, shuffle=True, random_state=1234)


def build_model(model_name):
    return model_name()

for model_name in [LinearRegression, Ridge, ElasticNet, \
                   AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor]:
    
    model = build_model(model_name)
    results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring='r2')
    print model_name, results.mean()
# Out:
# <class 'sklearn.linear_model.base.LinearRegression'> -0.012046398231992023
# <class 'sklearn.linear_model.ridge.Ridge'> -0.011783291897946257
# <class 'sklearn.linear_model.coordinate_descent.ElasticNet'> -0.010287623191565865
# <class 'sklearn.ensemble.weight_boosting.AdaBoostRegressor'> -0.06982396127569586
# <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'> 0.0009894293911655416
# <class 'sklearn.ensemble.forest.RandomForestRegressor'> -0.035032633097425034

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import explained_variance_score


degrees = [1, 2, 3, 4]


for d in degrees:

    polynomial_features = PolynomialFeatures(degree=d,
                                             include_bias=False, interaction_only=False)
    linear_regression = Ridge(normalize=True, alpha=0.5)
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    
    # The degree 
    print 'degree is: %s' % d
    
    # The mean squared error
    print("Mean squared error: %.2f"
          % mean_squared_error(y_test, y_pred))
    # Explained variance score: 1 is perfect prediction
    print('r2 score: %.2f' % r2_score(y_test.tolist(), y_pred.tolist()))
    
    # Explained variance score: 1 is perfect prediction
    print('explained variance score: %.2f' % explained_variance_score(y_test.tolist(), y_pred.tolist()))   
    plt.scatter(y_test.tolist(), (y_test-y_pred).tolist(), alpha=0.25)
    plt.show()
# Out:
# degree is: 1
# Mean squared error: 23.10
# r2 score: 0.04
# explained variance score: 0.04
# degree is: 2
# Mean squared error: 22.69
# r2 score: 0.06
# explained variance score: 0.06
# degree is: 3
# Mean squared error: 22.64
# r2 score: 0.06
# explained variance score: 0.06
# degree is: 4
# Mean squared error: 23.15
# r2 score: 0.04
# explained variance score: 0.04

# %%
import xgboost


xgb = xgboost.XGBRegressor(n_estimators=500, learning_rate=0.07, gamma=0, 
                          subsample=0.75, colsample_bytree=0.75, max_depth=50, 
                          objective='reg:linear')

xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test)

# %%
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('r2 score: %.2f' % r2_score(y_test.ravel(), y_pred.ravel(),))

# Explained variance score: 1 is perfect prediction
print('explained variance score: %.2f' % explained_variance_score(y_test.ravel(), y_pred.ravel()))   
plt.scatter(y_test.tolist(), (y_test-y_pred).tolist(), alpha=0.25)
plt.show()
# Out:
# Mean squared error: 27.61
# r2 score: -0.15
# explained variance score: -0.14

# %%
plt.scatter(y_test, y_pred, alpha=0.25)
plt.show()
